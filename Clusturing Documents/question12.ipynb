# %%
import random
random.seed(42)

import nltk
from nltk import pos_tag
from nltk.corpus import stopwords

import numpy as np

from matplotlib import pyplot as plt

from sklearn import metrics, preprocessing
import sklearn.cluster as clst
from sklearn.cluster import KMeans as KM
from sklearn.datasets import fetch_20newsgroups
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import NMF
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

import time

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
import pickle
import warnings; warnings.simplefilter('ignore')

# %%
twenty_train = fetch_20newsgroups(subset='all', categories=None, shuffle=True,
                                  random_state=42)
print(twenty_train.keys())

rs = [1,2,3,5,20,50,100,150,200,250,300]

num_clusters = 20

dim_techs = []

transform = []

# extract tfidf features:
vectorizer = CountVectorizer(min_df=3, stop_words='english')
tfidf_transformer = TfidfTransformer()
X_train_20 = vectorizer.fit_transform(twenty_train.data)
X_train_tfidf_20 = tfidf_transformer.fit_transform(X_train_20)
print(X_train_tfidf_20.shape)
# Out:
# dict_keys(['data', 'filenames', 'target_names', 'target', 'DESCR', 'description'])
# (18846, 52295)

# %%
def dim_red_svd(r):
    svd = TruncatedSVD(n_components=r, random_state=42)
    X_train_svd = svd.fit_transform(X_train_tfidf_20)
    return X_train_svd

def dim_red_nmf(r):
    nmf = NMF(n_components=r, random_state=42)
    X_train_nmf= nmf.fit_transform(X_train_tfidf_20)
    return X_train_nmf

def scores(km):
    return [metrics.cluster.contingency_matrix(twenty_train.target, km.labels_),
            metrics.homogeneity_score(twenty_train.target, km.labels_),
            metrics.completeness_score(twenty_train.target, km.labels_),
            metrics.v_measure_score(twenty_train.target, km.labels_),
            metrics.adjusted_rand_score(twenty_train.target, km.labels_),
            metrics.adjusted_mutual_info_score(twenty_train.target, km.labels_)]

def print_scores(scores_list):
    score_names= ['contingeny matrix', 'homogeneity_score', 'completeness_score', 'v_measure_score',
                  'adjusted_rand_score', 'adjusted_mutual_info_score']
    for i in range(1, 6):
        print(str(score_names[i]) + ' ' + str(scores_list[i]))

def apply_kmeans(X_train_dim_red):
    km = KM(n_clusters = num_clusters, random_state=0,
            max_iter = 1000, n_init = 30, n_jobs=-1)
    km.fit(X_train_dim_red)
    X_kmeans = km.predict(X_train_dim_red)
    return km, X_kmeans

def plain(X_dim_red):
    return X_dim_red

def normalize(X_dim_red):
    return preprocessing.scale(X_dim_red)

def log_transform(X_dim_red):
    c=0.01
    X_nonlinear = np.multiply(np.sign(X_dim_red),
                              (np.subtract(np.log10(
                                  abs(X_dim_red)+c), np.log10(c))))
    return X_nonlinear

def log_normalize(X_dim_red):
    return log_transform(normalize(X_dim_red))

def normalize_log(X_dim_red):
    return normalize(log_transform(X_dim_red))

# %%
dim_techs = [dim_red_svd, dim_red_nmf]
transforms = [plain, normalize, log_transform, log_normalize, normalize_log]
scores_log = []
best_tech = {}
best_tech['dim_red_svd'] = [0, '']
best_tech['dim_red_nmf'] = [0, '']

# %%
for dim_tech in dim_techs:
    for r in rs:
        X_dim_red = dim_tech(r)
        for transform in transforms:
            X_trans = transform(X_dim_red)
            km, _ = apply_kmeans(X_trans)
            scores_list = scores(km)
            if best_tech[dim_tech.__name__][0] < scores_list[3]:
                best_tech[dim_tech.__name__][0] = scores_list[3]
                best_tech[dim_tech.__name__][1] = str(r) + ' ' + transform.__name__
            scores_log.append(scores_list)
            print(dim_tech.__name__ + ' ' + str(r) + ' ' + transform.__name__)
            print_scores(scores_list)
            print('\n')
        print('\n')
    print('\n')
    print('Best technique: ' + best_tech[dim_tech.__name__][1] + 'Score is ' + str(best_tech[dim_tech.__name__][0]))
    print('\n\n\n')
# Out:
# dim_red_svd 1 plain
# homogeneity_score 0.02779545671734885
# completeness_score 0.030289905047271613
# v_measure_score 0.0289891194317001
# adjusted_rand_score 0.0058970947589372024
# adjusted_mutual_info_score 0.024627566992484234
#
#
# dim_red_svd 1 normalize
# homogeneity_score 0.02779545671734885
# completeness_score 0.030289905047271613
# v_measure_score 0.0289891194317001
# adjusted_rand_score 0.0058970947589372024
# adjusted_mutual_info_score 0.024627566992484234
#
#
# dim_red_svd 1 log_transform
# homogeneity_score 0.027700279498944567
# completeness_score 0.030887906630044655
# v_measure_score 0.02920737791423757
# adjusted_rand_score 0.0057301769189110315
# adjusted_mutual_info_score 0.0245177307686322
#
#
# dim_red_svd 1 log_normalize
# homogeneity_score 0.027182357883646285
# completeness_score 0.028815748829267213
# v_measure_score 0.027975231426235838
# adjusted_rand_score 0.008879181141351064
# adjusted_mutual_info_score 0.02403223780121439
#
#
# dim_red_svd 1 normalize_log
# homogeneity_score 0.027700279498944567
# completeness_score 0.030887906630044655
# v_measure_score 0.02920737791423757
# adjusted_rand_score 0.0057301769189110315
# adjusted_mutual_info_score 0.0245177307686322
#
#
#
#
# dim_red_svd 2 plain
# homogeneity_score 0.2108393156781899
# completeness_score 0.22472335387014905
# v_measure_score 0.2175600502955023
# adjusted_rand_score 0.06463815071297603
# adjusted_mutual_info_score 0.2082817285694378
#
#
# dim_red_svd 2 normalize
# homogeneity_score 0.19836307180519733
# completeness_score 0.21378432545169623
# v_measure_score 0.20578519133031453
# adjusted_rand_score 0.06132763105756929
# adjusted_mutual_info_score 0.19574743963762226
#
#
# dim_red_svd 2 log_transform
# homogeneity_score 0.2194282794099846
# completeness_score 0.2233551674739091
# v_measure_score 0.22137431035889787
# adjusted_rand_score 0.07289888013133783
# adjusted_mutual_info_score 0.21690850889465407
#
#
# dim_red_svd 2 log_normalize
# homogeneity_score 0.18809628811333812
# completeness_score 0.19514507266376468
# v_measure_score 0.19155585783973048
# adjusted_rand_score 0.06850685375229815
# adjusted_mutual_info_score 0.18547394929939887
#
#
# dim_red_svd 2 normalize_log
# homogeneity_score 0.19372337803097114
# completeness_score 0.2011681831628256
# v_measure_score 0.1973756029470092
# adjusted_rand_score 0.065852070150868
# adjusted_mutual_info_score 0.19109874787007294
#
#
#
#
# dim_red_svd 3 plain
# homogeneity_score 0.23275976941322776
# completeness_score 0.24237588222922632
# v_measure_score 0.237470517162773
# adjusted_rand_score 0.07955820268538429
# adjusted_mutual_info_score 0.23027991709247808
#
#
# dim_red_svd 3 normalize
# homogeneity_score 0.2124560138568149
# completeness_score 0.22200263862184755
# v_measure_score 0.2171244393371089
# adjusted_rand_score 0.07257429467059603
# adjusted_mutual_info_score 0.2099100058116429
#
#
# dim_red_svd 3 log_transform
# homogeneity_score 0.24412764325388084
# completeness_score 0.2470272799208431
# v_measure_score 0.24556890227908298
# adjusted_rand_score 0.09012325475600251
# adjusted_mutual_info_score 0.24168813775655085
#
#
# dim_red_svd 3 log_normalize
# homogeneity_score 0.1930886228858865
# completeness_score 0.19866444856455676
# v_measure_score 0.19583685533179954
# adjusted_rand_score 0.06728984353799845
# adjusted_mutual_info_score 0.19048339641750658
#
#
# dim_red_svd 3 normalize_log
# homogeneity_score 0.1936017846585294
# completeness_score 0.1997424119659322
# v_measure_score 0.1966241666228198
# adjusted_rand_score 0.06423193610626877
# adjusted_mutual_info_score 0.19097722685814061
#
#
#
#
# dim_red_svd 5 plain
# homogeneity_score 0.3130011900624332
# completeness_score 0.33166689922767145
# v_measure_score 0.3220638213282561
# adjusted_rand_score 0.12285314773692901
# adjusted_mutual_info_score 0.310779156151548
#
#
# dim_red_svd 5 normalize
# homogeneity_score 0.281710436375012
# completeness_score 0.29818880864439695
# v_measure_score 0.28971549843127137
# adjusted_rand_score 0.10886978806256137
# adjusted_mutual_info_score 0.2793871302758237
#
#
# dim_red_svd 5 log_transform
# homogeneity_score 0.3336160452735214
# completeness_score 0.3388304273687316
# v_measure_score 0.33620301926167195
# adjusted_rand_score 0.1459211424122614
# adjusted_mutual_info_score 0.3314651230019475
#
#
# dim_red_svd 5 log_normalize
# homogeneity_score 0.2883001737229111
# completeness_score 0.29101605706068473
# v_measure_score 0.28965174924675274
# adjusted_rand_score 0.11906365505253368
# adjusted_mutual_info_score 0.28600332836955183
#
#
# dim_red_svd 5 normalize_log
# homogeneity_score 0.3112184564528085
# completeness_score 0.31502267662042394
# v_measure_score 0.313109011809276
# adjusted_rand_score 0.1310922652316976
# adjusted_mutual_info_score 0.3089953728584212
#
#
#
#
# dim_red_svd 20 plain
# homogeneity_score 0.28775817497792594
# completeness_score 0.3833023952550472
# v_measure_score 0.32872859058003523
# adjusted_rand_score 0.09288355249332016
# adjusted_mutual_info_score 0.2854262970953409
#
#
# dim_red_svd 20 normalize
# homogeneity_score 0.2744920245008958
# completeness_score 0.37036612544979197
# v_measure_score 0.3153020477109277
# adjusted_rand_score 0.08393717931294298
# adjusted_mutual_info_score 0.2721167771156911
#
#
# dim_red_svd 20 log_transform
# homogeneity_score 0.361735207854921
# completeness_score 0.39593199914299093
# v_measure_score 0.3780618791036021
# adjusted_rand_score 0.19569906189476843
# adjusted_mutual_info_score 0.35966817009750507
#
#
# dim_red_svd 20 log_normalize
# homogeneity_score 0.34204952832860847
# completeness_score 0.35719477882374034
# v_measure_score 0.34945813464158026
# adjusted_rand_score 0.1948002468366569
# adjusted_mutual_info_score 0.33992383517068375
#
#
# dim_red_svd 20 normalize_log
# homogeneity_score 0.33301829630116786
# completeness_score 0.362714218961419
# v_measure_score 0.3472325027015624
# adjusted_rand_score 0.1739066895189898
# adjusted_mutual_info_score 0.3308591296806169
#
#
#
#
# dim_red_svd 50 plain
# homogeneity_score 0.31042414669362883
# completeness_score 0.4135682185351064
# v_measure_score 0.35464893693403593
# adjusted_rand_score 0.09390628001713353
# adjusted_mutual_info_score 0.3081631937023113
#
#
# dim_red_svd 50 normalize
# homogeneity_score 0.29718746763801984
# completeness_score 0.43626074267751364
# v_measure_score 0.35353886892827896
# adjusted_rand_score 0.08145921495263121
# adjusted_mutual_info_score 0.29487302930587433
#
#
# dim_red_svd 50 log_transform
# homogeneity_score 0.39519201371830204
# completeness_score 0.42047475740985535
# v_measure_score 0.40744154838791874
# adjusted_rand_score 0.20359331567623368
# adjusted_mutual_info_score 0.39323730327742934
#
#
# dim_red_svd 50 log_normalize
# homogeneity_score 0.3723265792480341
# completeness_score 0.3851764581264406
# v_measure_score 0.3786425294297407
# adjusted_rand_score 0.20359744485032327
# adjusted_mutual_info_score 0.3702998235464383
#
#
# dim_red_svd 50 normalize_log
# homogeneity_score 0.3770553330236111
# completeness_score 0.40038834838274084
# v_measure_score 0.3883716998384612
# adjusted_rand_score 0.19564613511259496
# adjusted_mutual_info_score 0.3750421458163474
#
#
#
#
# dim_red_svd 100 plain
# homogeneity_score 0.27521502255716407
# completeness_score 0.38151839262023823
# v_measure_score 0.31976321169096744
# adjusted_rand_score 0.08311391009711216
# adjusted_mutual_info_score 0.2728322908161792
#
#
# dim_red_svd 100 normalize
# homogeneity_score 0.1787393617339201
# completeness_score 0.30308004355263823
# v_measure_score 0.22486571916574716
# adjusted_rand_score 0.046547883901240386
# adjusted_mutual_info_score 0.1759759838677447
#
#
# dim_red_svd 100 log_transform
# homogeneity_score 0.41186326742222606
# completeness_score 0.4451609475118978
# v_measure_score 0.4278652555578429
# adjusted_rand_score 0.21258094788568635
# adjusted_mutual_info_score 0.409961969562572
#
#
# dim_red_svd 100 log_normalize
# homogeneity_score 0.40163535322277616
# completeness_score 0.4188721090461154
# v_measure_score 0.4100726811349175
# adjusted_rand_score 0.23531427010995806
# adjusted_mutual_info_score 0.39970287528329995
#
#
# dim_red_svd 100 normalize_log
# homogeneity_score 0.35320589470100106
# completeness_score 0.4054350531570763
# v_measure_score 0.37752259773956354
# adjusted_rand_score 0.14705869439230462
# adjusted_mutual_info_score 0.35111104485375855
#
#
#
#
# dim_red_svd 150 plain
# homogeneity_score 0.3030947499940975
# completeness_score 0.4625169654626473
# v_measure_score 0.3662077295442064
# adjusted_rand_score 0.07719498062656309
# adjusted_mutual_info_score 0.30080661969281824
#
#
# dim_red_svd 150 normalize
# homogeneity_score 0.1358736838622158
# completeness_score 0.22116079705908767
# v_measure_score 0.1683307009719639
# adjusted_rand_score 0.030231891877933834
# adjusted_mutual_info_score 0.1329850253786301
# dim_red_svd 150 log_transform
# homogeneity_score 0.4224179479331435
# completeness_score 0.4576390850613666
# v_measure_score 0.43932371643652257
# adjusted_rand_score 0.22950270621153734
# adjusted_mutual_info_score 0.4205485736064781
#
#
# dim_red_svd 150 log_normalize
# homogeneity_score 0.39072226283656203
# completeness_score 0.41282011357517845
# v_measure_score 0.4014673367715211
# adjusted_rand_score 0.21840375573526866
# adjusted_mutual_info_score 0.3887542324515173
#
#
# dim_red_svd 150 normalize_log
# homogeneity_score 0.3980794671635033
# completeness_score 0.4533374219031277
# v_measure_score 0.42391529149558704
# adjusted_rand_score 0.19297157511880977
# adjusted_mutual_info_score 0.3961309105280443
#
#
#
#
# dim_red_svd 200 plain
# homogeneity_score 0.23606881736175844
# completeness_score 0.40927913535216204
# v_measure_score 0.2994292956136741
# adjusted_rand_score 0.06023279975644719
# adjusted_mutual_info_score 0.2335192223745728
#
#
# dim_red_svd 200 normalize
# homogeneity_score 0.1493709612226473
# completeness_score 0.2537560844719587
# v_measure_score 0.18804885784014727
# adjusted_rand_score 0.031266132388708116
# adjusted_mutual_info_score 0.1465325178950785
#
#
# dim_red_svd 200 log_transform
# homogeneity_score 0.3939231086093317
# completeness_score 0.45213881240669757
# v_measure_score 0.4210281117303787
# adjusted_rand_score 0.1842538227761215
# adjusted_mutual_info_score 0.3919568884500627
#
#
# dim_red_svd 200 log_normalize
# homogeneity_score 0.405628975921874
# completeness_score 0.4379539147623419
# v_measure_score 0.42117212169141577
# adjusted_rand_score 0.20290516227762387
# adjusted_mutual_info_score 0.40370792749771944
#
#
# dim_red_svd 200 normalize_log
# homogeneity_score 0.3498991522595967
# completeness_score 0.3980970972963656
# v_measure_score 0.37244528149357536
# adjusted_rand_score 0.1665257859173278
# adjusted_mutual_info_score 0.3477913448219431
#
#
#
#
# dim_red_svd 250 plain
# homogeneity_score 0.2979188905189811
# completeness_score 0.4093282701217446
# v_measure_score 0.3448486777444175
# adjusted_rand_score 0.09226629048841892
# adjusted_mutual_info_score 0.29560065115410195
#
#
# dim_red_svd 250 normalize
# homogeneity_score 0.15394649950524275
# completeness_score 0.2583285620604082
# v_measure_score 0.19292351907193833
# adjusted_rand_score 0.03591960178996624
# adjusted_mutual_info_score 0.1510824442262425
#
#
# dim_red_svd 250 log_transform
# homogeneity_score 0.46881102124276625
# completeness_score 0.5263198348329076
# v_measure_score 0.4959037050491699
# adjusted_rand_score 0.25287439275908397
# adjusted_mutual_info_score 0.4670916644490939
#
#
# dim_red_svd 250 log_normalize
# homogeneity_score 0.39986927401281164
# completeness_score 0.4445828857440911
# v_measure_score 0.4210422904529905
# adjusted_rand_score 0.18822284253062893
# adjusted_mutual_info_score 0.3979256101959405
#
#
# dim_red_svd 250 normalize_log
# homogeneity_score 0.3485396952960645
# completeness_score 0.41109399971887545
# v_measure_score 0.3772412370339609
# adjusted_rand_score 0.15782497632992223
# adjusted_mutual_info_score 0.34642199112141303
#
#
#
#
# dim_red_svd 300 plain
# homogeneity_score 0.28111990777346324
# completeness_score 0.46134428891786244
# v_measure_score 0.34935843244794856
# adjusted_rand_score 0.07046919956561455
# adjusted_mutual_info_score 0.2787230045001188
#
#
# dim_red_svd 300 normalize
# homogeneity_score 0.15095245145579037
# completeness_score 0.24199991220702263
# v_measure_score 0.18592828738438338
# adjusted_rand_score 0.03340011539058542
# adjusted_mutual_info_score 0.14813072715195744
#
#
# dim_red_svd 300 log_transform
# homogeneity_score 0.37544507403519073
# completeness_score 0.43461559222430995
# v_measure_score 0.4028692911432682
# adjusted_rand_score 0.1811646601342211
# adjusted_mutual_info_score 0.37341971128578144
#
#
# dim_red_svd 300 log_normalize
# homogeneity_score 0.3174372225412755
# completeness_score 0.35409321552337675
# v_measure_score 0.33476477158769774
# adjusted_rand_score 0.14526442468786827
# adjusted_mutual_info_score 0.31522498995488946
#
#
# dim_red_svd 300 normalize_log
# homogeneity_score 0.3592407780178232
# completeness_score 0.4348115541708246
# v_measure_score 0.3934300918956461
# adjusted_rand_score 0.15346360778913187
# adjusted_mutual_info_score 0.3571473454551032
#
#
#
#
#
#
# Best technique: 250 log_transformScore is 0.4959037050491699
#
#
#
#
# dim_red_nmf 1 plain
# homogeneity_score 0.027797388442368152
# completeness_score 0.030291743624911993
# v_measure_score 0.028991012059297015
# adjusted_rand_score 0.005897198033102118
# adjusted_mutual_info_score 0.02462950606990766
#
#
# dim_red_nmf 1 normalize
# homogeneity_score 0.027797388442368152
# completeness_score 0.030291743624911993
# v_measure_score 0.028991012059297015
# adjusted_rand_score 0.005897198033102118
# adjusted_mutual_info_score 0.02462950606990766
#
#
# dim_red_nmf 1 log_transform
# homogeneity_score 0.027883558125483245
# completeness_score 0.03013682974597231
# v_measure_score 0.02896644006590748
# adjusted_rand_score 0.005719300858384661
# adjusted_mutual_info_score 0.02469996024946043
#
#
# dim_red_nmf 1 log_normalize
# homogeneity_score 0.027162997567351185
# completeness_score 0.028797821956113072
# v_measure_score 0.027956530100883257
# adjusted_rand_score 0.008896434224620891
# adjusted_mutual_info_score 0.024012896774156113
#
#
# dim_red_nmf 1 normalize_log
# homogeneity_score 0.027883558125483245
# completeness_score 0.03013682974597231
# v_measure_score 0.02896644006590748
# adjusted_rand_score 0.005719300858384661
# adjusted_mutual_info_score 0.02469996024946043
#
#
#
#
# dim_red_nmf 2 plain
# homogeneity_score 0.16929988844690222
# completeness_score 0.1799339171367996
# v_measure_score 0.17445500184702606
# adjusted_rand_score 0.05100722802800033
# adjusted_mutual_info_score 0.16659160361797618
#
#
# dim_red_nmf 2 normalize
# homogeneity_score 0.16694156900838714
# completeness_score 0.17949634347365925
# v_measure_score 0.17299146618263936
# adjusted_rand_score 0.048474544270092804
# adjusted_mutual_info_score 0.1642246421773223
#
#
# dim_red_nmf 2 log_transform
# homogeneity_score 0.17726050186582995
# completeness_score 0.18260293466523642
# v_measure_score 0.17989206212751138
# adjusted_rand_score 0.056043529659153
# adjusted_mutual_info_score 0.17460394762935152
#
#
# dim_red_nmf 2 log_normalize
# homogeneity_score 0.1607325737984692
# completeness_score 0.17434938059491664
# v_measure_score 0.1672643024535432
# adjusted_rand_score 0.06528771789264794
# adjusted_mutual_info_score 0.15801772958769555
#
#
# dim_red_nmf 2 normalize_log
# homogeneity_score 0.178577224156302
# completeness_score 0.18305679431582864
# v_measure_score 0.18078926495899358
# adjusted_rand_score 0.05587068557114052
# adjusted_mutual_info_score 0.17592519866201556
#
#
#
#
# dim_red_nmf 3 plain
# homogeneity_score 0.19178000627523362
# completeness_score 0.20960625942315464
# v_measure_score 0.20029728559624832
# adjusted_rand_score 0.05719284434049654
# adjusted_mutual_info_score 0.189156747796646
#
#
# dim_red_nmf 3 normalize
# homogeneity_score 0.18509822718869604
# completeness_score 0.19729834404514676
# v_measure_score 0.19100366717299708
# adjusted_rand_score 0.054730024848027796
# adjusted_mutual_info_score 0.1824601111565797
#
#
# dim_red_nmf 3 log_transform
# homogeneity_score 0.20586787449072014
# completeness_score 0.2120187403454655
# v_measure_score 0.20889804017403682
# adjusted_rand_score 0.0710399139378034
# adjusted_mutual_info_score 0.20330342448126323
#
#
# dim_red_nmf 3 log_normalize
# homogeneity_score 0.18538006417809813
# completeness_score 0.20111233379798846
# v_measure_score 0.19292600600534943
# adjusted_rand_score 0.0855614193524248
# adjusted_mutual_info_score 0.18274577190647734
#
#
# dim_red_nmf 3 normalize_log
# homogeneity_score 0.20385207527895044
# completeness_score 0.2092678135856294
# v_measure_score 0.20652444599443084
# adjusted_rand_score 0.07015373868843193
# adjusted_mutual_info_score 0.20128134755138768
#
#
#
#
# dim_red_nmf 5 plain
# homogeneity_score 0.29247610247999617
# completeness_score 0.309899427401048
# v_measure_score 0.3009357857047748
# adjusted_rand_score 0.10514081325155411
# adjusted_mutual_info_score 0.2901862243175811
#
#
# dim_red_nmf 5 normalize
# homogeneity_score 0.28535500294397675
# completeness_score 0.3018518784081299
# v_measure_score 0.29337171067703394
# adjusted_rand_score 0.09989546580942173
# adjusted_mutual_info_score 0.28304480437054463
#
#
# dim_red_nmf 5 log_transform
# homogeneity_score 0.31243381597625663
# completeness_score 0.31569182325471634
# v_measure_score 0.31405437018215376
# adjusted_rand_score 0.12723553002226165
# adjusted_mutual_info_score 0.3102147972447175
# dim_red_nmf 5 log_normalize
# homogeneity_score 0.2789982455985024
# completeness_score 0.3047802694483108
# v_measure_score 0.2913199382210863
# adjusted_rand_score 0.1297529419419758
# adjusted_mutual_info_score 0.27666274302127725
#
#
# dim_red_nmf 5 normalize_log
# homogeneity_score 0.30932091333637957
# completeness_score 0.31284585823845973
# v_measure_score 0.3110734003324497
# adjusted_rand_score 0.1220918891386104
# adjusted_mutual_info_score 0.307091804598393
#
#
#
#
# dim_red_nmf 20 plain
# homogeneity_score 0.2833502674383202
# completeness_score 0.3732318438209899
# v_measure_score 0.32213897073844555
# adjusted_rand_score 0.09417972886331091
# adjusted_mutual_info_score 0.281003829281312
#
#
# dim_red_nmf 20 normalize
# homogeneity_score 0.273521164601938
# completeness_score 0.36274719494038016
# v_measure_score 0.31187794812726327
# adjusted_rand_score 0.08655020655783453
# adjusted_mutual_info_score 0.27114196323392725
#
#
# dim_red_nmf 20 log_transform
# homogeneity_score 0.3644197782299894
# completeness_score 0.40394915903841
# v_measure_score 0.3831676576523215
# adjusted_rand_score 0.19990969890200733
# adjusted_mutual_info_score 0.3623602745787723
#
#
# dim_red_nmf 20 log_normalize
# homogeneity_score 0.3074326940640203
# completeness_score 0.31112463077994307
# v_measure_score 0.30926764452908245
# adjusted_rand_score 0.14688044480807566
# adjusted_mutual_info_score 0.3051974837221326
#
#
# dim_red_nmf 20 normalize_log
# homogeneity_score 0.35417211130264653
# completeness_score 0.39233130791635834
# v_measure_score 0.3722764131482168
# adjusted_rand_score 0.19564733444204424
# adjusted_mutual_info_score 0.3520811139074377
#
#
#
#
# dim_red_nmf 50 plain
# homogeneity_score 0.18291390543519667
# completeness_score 0.35041484599685374
# v_measure_score 0.24036111997207313
# adjusted_rand_score 0.032384487952483436
# adjusted_mutual_info_score 0.18020402892597664
#
#
# dim_red_nmf 50 normalize
# homogeneity_score 0.30534649338511516
# completeness_score 0.4521384755897276
# v_measure_score 0.36451917516636545
# adjusted_rand_score 0.10433555029428847
# adjusted_mutual_info_score 0.3030401465030637
#
#
# dim_red_nmf 50 log_transform
# homogeneity_score 0.3715859859311795
# completeness_score 0.41399230731163206
# v_measure_score 0.39164457827698335
# adjusted_rand_score 0.1947246927356793
# adjusted_mutual_info_score 0.3695536072919534
#
#
# dim_red_nmf 50 log_normalize
# homogeneity_score 0.33170497484985545
# completeness_score 0.33388572267883687
# v_measure_score 0.3327917762526575
# adjusted_rand_score 0.1833185695263242
# adjusted_mutual_info_score 0.3295484539867825
#
#
# dim_red_nmf 50 normalize_log
# homogeneity_score 0.4742337074326527
# completeness_score 0.55495969230306
# v_measure_score 0.5114307814724552
# adjusted_rand_score 0.26619848597864704
# adjusted_mutual_info_score 0.47252378805843137
#
#
#
#
# dim_red_nmf 100 plain
# homogeneity_score 0.10763311023362854
# completeness_score 0.31255204783731266
# v_measure_score 0.16012440407492975
# adjusted_rand_score 0.005728590724525346
# adjusted_mutual_info_score 0.1046305514765051
#
#
# dim_red_nmf 100 normalize
# homogeneity_score 0.3579193238291397
# completeness_score 0.504781198271071
# v_measure_score 0.4188497411060058
# adjusted_rand_score 0.10387952824539835
# adjusted_mutual_info_score 0.3557895534298067
#
#
# dim_red_nmf 100 log_transform
# homogeneity_score 0.26216457918069686
# completeness_score 0.31020192084835435
# v_measure_score 0.28416742082607893
# adjusted_rand_score 0.10849120936915799
# adjusted_mutual_info_score 0.2597712522410052
#
#
# dim_red_nmf 100 log_normalize
# homogeneity_score 0.373728666267725
# completeness_score 0.37935376744074506
# v_measure_score 0.3765202086871404
# adjusted_rand_score 0.22565668494215285
# adjusted_mutual_info_score 0.37170734748567974
#
#
# dim_red_nmf 100 normalize_log
# homogeneity_score 0.44020986543199553
# completeness_score 0.5234129345223802
# v_measure_score 0.4782193561264264
# adjusted_rand_score 0.2224055989892315
# adjusted_mutual_info_score 0.43838504624226005
#
#
#
#
# dim_red_nmf 150 plain
# homogeneity_score 0.06396017791148503
# completeness_score 0.16686810266056581
# v_measure_score 0.09247492124857111
# adjusted_rand_score 0.006443504735172476
# adjusted_mutual_info_score 0.060728994501188086
#
#
# dim_red_nmf 150 normalize
# homogeneity_score 0.330958190990023
# completeness_score 0.47497227327091923
# v_measure_score 0.3900980824104095
# adjusted_rand_score 0.09431118765164263
# adjusted_mutual_info_score 0.3287210274365802
#
#
# dim_red_nmf 150 log_transform
# homogeneity_score 0.12498705070001487
# completeness_score 0.1680323009738744
# v_measure_score 0.1433479502366482
# adjusted_rand_score 0.027093694593839
# adjusted_mutual_info_score 0.12213963170316486
#
#
# dim_red_nmf 150 log_normalize
# homogeneity_score 0.3713420236677354
# completeness_score 0.3806126597179241
# v_measure_score 0.375920194171394
# adjusted_rand_score 0.22096358835181995
# adjusted_mutual_info_score 0.36931255485709247
#
#
# dim_red_nmf 150 normalize_log
# homogeneity_score 0.39194711471665955
# completeness_score 0.5509037205645031
# v_measure_score 0.458026053925147
# adjusted_rand_score 0.16719560563352248
# adjusted_mutual_info_score 0.3899422887014935
#
#
#
#
# dim_red_nmf 200 plain
# homogeneity_score 0.07038327859409962
# completeness_score 0.29299416304078274
# v_measure_score 0.11350121081244832
# adjusted_rand_score 0.0019012366710494898
# adjusted_mutual_info_score 0.06721132305963139
#
#
# dim_red_nmf 200 normalize
# homogeneity_score 0.3122039058855241
# completeness_score 0.5310159166394065
# v_measure_score 0.3932195112913229
# adjusted_rand_score 0.08043668986731839
# adjusted_mutual_info_score 0.30984401763323505
#
#
# dim_red_nmf 200 log_transform
# homogeneity_score 0.1560924808567547
# completeness_score 0.21853372912202335
# v_measure_score 0.18210937206698383
# adjusted_rand_score 0.02935958660610871
# adjusted_mutual_info_score 0.15334871083714216
#
#
# dim_red_nmf 200 log_normalize
# homogeneity_score 0.3668850943265883
# completeness_score 0.3752288737282918
# v_measure_score 0.3710100783918496
# adjusted_rand_score 0.21298231317213512
# adjusted_mutual_info_score 0.3648413848173361
#
#
# dim_red_nmf 200 normalize_log
# homogeneity_score 0.4252126639786234
# completeness_score 0.5403981478210075
# v_measure_score 0.4759353007156798
# adjusted_rand_score 0.19187257044734923
# adjusted_mutual_info_score 0.4233366579525653
#
#
#
#
# dim_red_nmf 250 plain
# homogeneity_score 0.08827044675044783
# completeness_score 0.2906848923148821
# v_measure_score 0.13541904632628493
# adjusted_rand_score 0.005268217569191619
# adjusted_mutual_info_score 0.08518680093721684
#
#
# dim_red_nmf 250 normalize
# homogeneity_score 0.3326311618242844
# completeness_score 0.5198695274500109
# v_measure_score 0.4056883638650048
# adjusted_rand_score 0.08723261323397453
# adjusted_mutual_info_score 0.3303934429285747
#
#
# dim_red_nmf 250 log_transform
# homogeneity_score 0.17970854551790696
# completeness_score 0.2305833780096095
# v_measure_score 0.20199180684059265
# adjusted_rand_score 0.04382594108089303
# adjusted_mutual_info_score 0.17704439880990622
#
#
# dim_red_nmf 250 log_normalize
# homogeneity_score 0.3119261270861548
# completeness_score 0.3184500242122807
# v_measure_score 0.3151543170484009
# adjusted_rand_score 0.16451688408274515
# adjusted_mutual_info_score 0.3097050527641644
#
#
# dim_red_nmf 250 normalize_log
# homogeneity_score 0.4342764232108897
# completeness_score 0.5374972284465503
# v_measure_score 0.48040482154957237
# adjusted_rand_score 0.18895846875006536
# adjusted_mutual_info_score 0.432437869315062
#
#
#
#
# dim_red_nmf 300 plain
# homogeneity_score 0.09181911352527347
# completeness_score 0.20063811957426772
# v_measure_score 0.12598364611086094
# adjusted_rand_score 0.010396433132016944
# adjusted_mutual_info_score 0.08876612939859342
#
#
# dim_red_nmf 300 normalize
# homogeneity_score 0.34826501790501874
# completeness_score 0.535924887209123
# v_measure_score 0.42218055049053327
# adjusted_rand_score 0.11568222456715037
# adjusted_mutual_info_score 0.3460604545371138
#
#
# dim_red_nmf 300 log_transform
# homogeneity_score 0.19612658652244264
# completeness_score 0.2390809303229348
# v_measure_score 0.21548399304650104
# adjusted_rand_score 0.056103704265908994
# adjusted_mutual_info_score 0.19350468869447796
#
#
# dim_red_nmf 300 log_normalize
# homogeneity_score 0.3711368417843116
# completeness_score 0.38437992754458056
# v_measure_score 0.37764231886182353
# adjusted_rand_score 0.19803295451208178
# adjusted_mutual_info_score 0.3691063814280539
#
#
# dim_red_nmf 300 normalize_log
# homogeneity_score 0.44767007118223656
# completeness_score 0.5416245740381059
# v_measure_score 0.4901858365152337
# adjusted_rand_score 0.22352351921074076
# adjusted_mutual_info_score 0.44585241116481683
#
#
#
#
#
#
# Best technique: 50 normalize_logScore is 0.5114307814724552

# %%
import pickle
pickle_out = open("list_scores1","wb")
pickle.dump(scores_list, pickle_out)
pickle_out.close()

# %%
print('Best technique of dim_red_svd: ' + best_tech['dim_red_svd'][1] + 'Score is ' + str(best_tech['dim_red_svd'][0]))
# Out:
# Best technique of dim_red_svd: 250 log_transformScore is 0.4959037050491699

# %%
print('Best technique of dim_red_nmf: ' + best_tech['dim_red_nmf'][1] + 'Score is ' + str(best_tech['dim_red_nmf'][0]))
# Out:
# Best technique of dim_red_nmf: 50 normalize_logScore is 0.5114307814724552

# %% [markdown]
# # Results:

# %% [markdown]
# |Dim Redn|r value|Transformation|V-measure|
# |--------------
# | SVD | 250 | Non linear Log | 0.4959|
# | NMF | 50 | Normalize-Non-linear Log | 0.5114|

# %%
np.save("scores", np.array(scores_log))

# %% [markdown]
# **Table of best transforms for each value of r and dimensionality reduction.**

# %% [markdown]
# |Dim Redn|r value|Transformation|V-measure|
# |--------------
# |svd | 1 | Nonlinear log | 0.02920737791423757|
# |svd | 2 | Nonlinear log | 0.22137431035889787|
# |svd | 3 | Nonlinear log | 0.24556890227908298|
# |svd | 5 | Nonlinear log | 0.33620301926167195|
# |svd | 20 | Nonlinear log | 0.3780618791036021|
# |svd | 50 | Nonlinear log | 0.40744154838791874|
# |svd | 100 | Nonlinear log | 0.4278652555578429|
# |svd | 150 | Nonlinear log | 0.43932371643652257|
# |svd | 200 | log normalize | 0.42117212169141577|
# |**svd** | **250** | **Nonlinear log** | **0.4959037050491699**|
# |svd | 300 | Nonlinear log | 0.4028692911432682|
# |nmf | 1 | plain | 0.028991012059297015|
# |nmf | 2 | normalize log | 0.18078926495899358|
# |nmf | 3 | Nonlinear log | 0.20889804017403682|
# |nmf | 5 | Nonlinear log | 0.31405437018215376|
# |nmf | 20 | Nonlinear log | 0.3831676576523215|
# |**nmf** | **50** | **normalize log** | **0.5114307814724552**|
# |nmf | 100 | normalize log | 0.4782193561264264|
# |nmf | 150 | normalize log | 0.458026053925147|
# |nmf | 200 | normalize log | 0.4759353007156798|
# |nmf | 250 | normalize log | 0.48040482154957237|
# |nmf | 300 | normalize log | 0.4901858365152337|

# %% [markdown]
# **The best result for SVD has been for r=250 and Log transform(data).**
#
# **The best fresult for NMF has been for r=50 and Normalize(Log transform(data)).**
